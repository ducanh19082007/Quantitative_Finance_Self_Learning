# %% [markdown]
# # Introduction to RL
#
# state of anything: **s_t** as the state of anything in time t
#
# observation $o_t$ on what the agent ovserves at time t
#
# action $a_t$ the decision at time t
#
# trajectory $\tri$
