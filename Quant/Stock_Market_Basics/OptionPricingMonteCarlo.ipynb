# %% [markdown]
# # The whole idea of using Monte Carlo for BS equation is through Feynman-Kac theorem that if V is the solution to the Black Sholes Equations, it mosty be the Arbitrage Free Price Implied by the Fundamental Theorem of Asset Pricing $$ V(t,S) = \mathbb{E}^Q[e^{-e (T - t)Payoff(S_t)} | S_t = S] $$

# %%
import os
import sys
sys.path.insert(0, os.getcwd())

import cppimport
import pybind11
os.environ["CPLUS_INCLUDE_PATH"] = pybind11.get_include()

opt_module = cppimport.imp("BruteForceOptionsPricing")

# Example usage
opt_module = opt_module.BruteForceOptionPricing(10.0, 100.0, 1.0, 100.0, 0.05, 1e-6, 0.2, 0.0)
print('Call price:', opt_module.OptionValue('Call'))
# Out:
# /home/ducanh19082007/Quantitative_Finance_Self_Learning/Quant/Stock_Market_Basics/.rendered.BruteForceOptionsPricing.cpp:2:10: fatal error: pybind11/pybind11.h: No such file or directory
#     2 | #include <pybind11/pybind11.h>
#       |          ^~~~~~~~~~~~~~~~~~~~~
# compilation terminated.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: error: command '/usr/bin/x86_64-linux-gnu-g++' failed with exit code 1
# /home/ducanh19082007/Quantitative_Finance_Self_Learning/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3756: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
